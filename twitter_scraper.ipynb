# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
import re  
import spacy
# nlp = spacy.load('en_core_web_lg')
# Out:
# [nltk_data] Downloading package punkt to /home/mario/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/mario/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from twitterscraper import query_tweets
from twitterscraper.query import query_tweets_from_user
import datetime as dt 
import pandas as pd

# %%
# begin_date = dt.date(2019,8,1)
# end_date = dt.date(2020,11,20)


# limit = 100
# lang = 'english'

#Use this to search a specific user

# user = 'nithyavraman'
# tweets = query_tweets_from_user(user)
# df = pd.DataFrame(t.__dict__ for t in tweets)

# df = df.loc[df['screen_name'] == user]

# df = df['text']

# df

#Use this if wanting to seach for a specific Phrase or word

#tweets = query_tweets('impeachment', begindate = begin_date, enddate = end_date, limit = limit, lang = lang)
#df = pd.DataFrame(t.__dict__ for t in tweets)

#df = df['text']

#df

# tweets

# %%
import re
import csv
from getpass import getpass
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import Firefox

# %%
# !export PATH=$PATH:~/Drivers/geckodriver

driver = Firefox()

# %%
def get_tweet_data(card):
    """Extract data from tweet card"""
    try:
        username = card.find_element_by_xpath('.//span').text
    except:
        pass
    try:
        handle = card.find_element_by_xpath('.//span[contains(text(), "@")]').text
    except NoSuchElementException:
        return
    
    try:
        postdate = card.find_element_by_xpath('.//time').get_attribute('datetime')
    except NoSuchElementException:
        return
    
    try:
        comment = card.find_element_by_xpath('.//div[2]/div[2]/div[1]').text
    except NoSuchElementException:
        pass
    
    try:
        responding = card.find_element_by_xpath('.//div[2]/div[2]/div[2]').text
    except NoSuchElementException:
        pass

    try:
        text = comment + responding
    except NoSuchElementException:
        pass
    
    try:
        reply_cnt = card.find_element_by_xpath('.//div[@data-testid="reply"]').text
    except NoSuchElementException:
        pass
    
    try:
        retweet_cnt = card.find_element_by_xpath('.//div[@data-testid="retweet"]').text
    except NoSuchElementException:
        pass
    
    try:
        like_cnt = card.find_element_by_xpath('.//div[@data-testid="like"]').text
    except NoSuchElementException:
        like_cnt = '0'
    
    
    
    
    
    
    
    # get a string of all emojis contained in the tweet
    """Emojis are stored as images... so I convert the filename, which is stored as unicode, into 
    the emoji character."""
    emoji_tags = card.find_elements_by_xpath('.//img[contains(@src, "emoji")]')
    emoji_list = []
    for tag in emoji_tags:
        filename = tag.get_attribute('src')
        try:
            emoji = chr(int(re.search(r'svg\/([a-z0-9]+)\.svg', filename).group(1), base=16))
        except AttributeError:
            continue
        if emoji:
            emoji_list.append(emoji)
    emojis = ' '.join(emoji_list)
    
    tweet = (username, handle, postdate, text, emojis, reply_cnt, retweet_cnt, like_cnt)
    return tweet

# %%
driver.get(url='https://www.twitter.com/login')

username = driver.find_element_by_xpath('//input[@name="session[username_or_email]"]')
username.send_keys("mario.b.k.parks@gmail.com")

# %%
my_password = getpass()
# Out:
# ········

# %%
password = driver.find_element_by_xpath('//input[@name="session[password]"]')
password.send_keys(my_password)
password.send_keys(Keys.RETURN)
sleep(1)

# %%
# search_term =

# %%
# find search input and search for term
search_input = driver.find_element_by_xpath('//input[@aria-label="Search query"]')
search_input.send_keys("nithyavraman")
search_input.send_keys(Keys.RETURN)
sleep(1)

# %%
# navigate to 'People' tab
driver.find_element_by_link_text('People').click()

# %%
# navigate to 'People' tab
driver.find_element_by_link_text('@nithyavraman').click()

# %%
# get all tweets on the page
data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                data.append(tweet)
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break

# %%
len(data)
# Out:
# 543

# %%
raman_data = data

# %%
ryu_data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                ryu_data.append(tweet)
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break

# %%
raman_data
# Out:
# [('Nithya Raman',
#   '@nithyavraman',
#   '2020-11-04T01:22:32.000Z',
#   'This campaign was never about any one person. We’ve built a community together — and I’m so proud, honored, and inspired to have been a part of it with all of you.1:17\n140.2K views',
#   '',
#   '57',
#   '261',
#   '2K'),
#  ('Nithya Raman',
#   '@nithyavraman',
#   '2020-11-17T22:32:56.000Z',
#   "Very excited to be joining \n@PplsAction\n and some really incredible guests this evening to talk about how we can continue to build power for big change at the local level!People's Action\n@PplsAction\n · Nov 17\nTONIGHT @ 8PM ET we're celebrating our electoral wins and laying the groundwork for big structural change! \n\nJoin us, Rep. @IlhanMN , Councilwoman @nithyavraman , Dr. @AbdulElSayed, and @NaomiAKlein! Feat. musical guest @headandtheheart!\n\nRSVP: http://ppls.ac/town-hall",
#   '',
#   '3',
#   '26',
#   '190'),
#  ('Nithya Raman',
#   '@nithyavraman',
#   '2020-11-07T01:58:36.000Z',
# ...

# %%
with open('nithyas_tweets.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(raman_data)

# %%
ryu_data
# Out:
# [('David E. Ryu',
#   '@davideryu',
#   '2020-06-25T00:35:29.000Z',
#   'All together now: WEAR A MASK.LosFelizLedger\n@LosFelizLedger\n · Jun 24\nLA Mayor Garcetti says that 40% of #COVID19 infections are now among the 18-40 age group. #coronavirus\nShow this thread',
#   '',
#   '41',
#   '25',
#   '78'),
#  ('Gavin Newsom',
#   '@GavinNewsom',
#   '2020-11-19T22:17:04.000Z',
#   'Due to the rise in #COVID19 cases, CA is issuing a limited Stay at Home Order.\n\nNon-essential work and gatherings must stop from 10pm-5am in counties in the purple tier.\n\nThis will take effect at 10pm on Saturday and remain for 1 month.\n\nTogether--we can flatten the curve again.',
#   '',
#   '28K',
#   '29.5K',
#   '52.6K'),
#  ('Los Angeles County',
#   '@CountyofLA',
#   '2020-11-02T23:36:08.000Z',
# ...

# %%
with open('davids_tweets.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(ryu_data)

# %%
lacd4_data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                lacd4_data.append(tweet)
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break

# %%
with open('lacd4_tweets.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(lacd4_data)

# %%
len(lacd4_data)
# Out:
# 499

# %%
atnithya_data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                atnithya_data.append(tweet)
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-38dc1e270264> in <module>
#       5
#       6 while scrolling:
# ----> 7     page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
#       8     for card in page_cards[-15:]:
#       9         tweet = get_tweet_data(card)
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_elements_by_xpath(self, xpath)
#     408             elements = driver.find_elements_by_xpath("//div[contains(@class, 'foo')]")
#     409         """
# --> 410         return self.find_elements(by=By.XPATH, value=xpath)
#     411
#     412     def find_element_by_link_text(self, link_text):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_elements(self, by, value)
#    1005         return self.execute(Command.FIND_ELEMENTS, {
# ...

# %%
len(atnithya_data)
# Out:
# 2366

# %%
with open('atnithya_tweets.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(atnithya_data)

# %%
atryu_data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                atryu_data.append(tweet)
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-130-5aa6544a14ea> in <module>
#      19         driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
#      20         sleep(2)
# ---> 21         curr_position = driver.execute_script("return window.pageYOffset;")
#      22         if last_position == curr_position:
#      23             scroll_attempt += 1
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
# ...

# %%
len(atryu_data)
# Out:
# 1879

# %%
with open('atryu_tweets.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(atryu_data)

# %%
atlacc_data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                atlacc_data.append(tweet)
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-157-3bbb46a076dd> in <module>
#       7     page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
#       8     for card in page_cards[-15:]:
# ----> 9         tweet = get_tweet_data(card)
#      10         if tweet:
#      11             tweet_id = ''.join(tweet)
#
# <ipython-input-139-1a806c2c41a3> in get_tweet_data(card)
#      31
#      32     try:
# ---> 33         reply_cnt = card.find_element_by_xpath('.//div[@data-testid="reply"]').text
#      34     except NoSuchElementException:
#      35         pass
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_xpath(self, xpath)
#     349             element = element.find_element_by_xpath('//div/td[1]')
#     350         """
# --> 351         return self.find_element(by=By.XPATH, value=xpath)
# ...

# %%
len(atlacc_data)
# Out:
# 2027

# %%
with open('atlacc_tweets.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(atlacc_data)

# %%
# get all tweets on the page
david_tr_data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                david_tr_data.append(tweet)
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break

# %%
len(david_tr_data)
# Out:
# 2263

# %%
with open('david_tweets_replies.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(david_tr_data)

# %%
# get all tweets on the page
old_nithya_data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                old_nithya_data.append(tweet)
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break

# %%
len(old_nithya_data)
# Out:
# 1191

# %%
with open('pre2019_nithya.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(old_nithya_data)

# %%
old_david_data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                old_david_data.append(tweet)
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break

# %%
len(old_david_data)
# Out:
# 3408

# %%
with open('pre2019_david.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(old_david_data)

# %%
trump_data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-20:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                trump_data.append(tweet)
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break

# %%
len(trump_data)
# Out:
# 3895

# %%
with open('trump.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(trump_data)
